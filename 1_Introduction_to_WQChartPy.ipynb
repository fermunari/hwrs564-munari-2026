# %% [markdown]
# # Introduction to Hydrogeochemical Data Visualization with WQChartPy
#
# ## Learning Objectives
# By the end of this notebook, you will be able to:
# 1. Understand the basics of hydrogeochemical data visualization
# 2. Install and import WQChartPy
# 3. Load and prepare water chemistry data for plotting
# 4. Create basic hydrogeochemical diagrams
# 5. Interpret common hydrogeochemical plots
#
# ## What is WQChartPy?
#
# WQChartPy is a Python package for creating geochemical diagrams used in water quality analysis and hydrogeochemistry. It can generate 12 different types of diagrams including:
#
# - **Piper diagrams** (Triangle, Rectangle, Color-coded, Contour-filled)
# - **Stiff diagrams**
# - **Durov diagrams**
# - **Schoeller diagrams**
# - **Gibbs diagrams**
# - **Chadha diagrams**
# - **Gaillardet diagrams**
# - **HFE-D diagrams**
# - **Chernoff faces**

# %% [markdown]
# ## Installation and Setup

# %%
from wqchartpy import triangle_piper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from wqchartpy import triangle_piper
#
# ModuleNotFoundError: No module named 'wqchartpy'

# %%
import pandas as pd
from wqchartpy import triangle_piper

# Read file
df = pd.read_excel("piperplot1.xlsx")
df.columns = [c.strip() for c in df.columns]

# Standardize names (edit if your headers differ)
rename_map = {
    "Ca": "Ca", "Mg": "Mg", "Na": "Na", "K": "K",
    "Cl": "Cl", "SO4": "SO4", "HCO3": "HCO3", "CO3": "CO3",
    "Sample": "Sample", "Sample_ID": "Sample", "ID": "Sample"
}
df = df.rename(columns={c: rename_map.get(c.lower(), c) for c in df.columns})

required = ["Ca", "Mg", "Na", "K", "Cl", "SO4", "HCO3"]
if "CO3" not in df.columns:
    df["CO3"] = 0.0

chem_cols = ["Ca","Mg","Na","K","Cl","SO4","HCO3","CO3"]
df[chem_cols] = df[chem_cols].apply(pd.to_numeric, errors="coerce")
df = df.dropna(subset=required).copy()

# ---- Convert meq/L -> mg/L using equivalent weights (mg/meq) ----
eq_wt = {
    "Ca": 40.078/2,      # 20.039
    "Mg": 24.305/2,      # 12.1525
    "Na": 22.989/1,      # 22.989
    "K": 39.098/1,       # 39.098
    "Cl": 35.453/1,      # 35.453
    "SO4": 96.06/2,      # 48.03
    "HCO3": 61.016/1,    # 61.016
    "CO3": 60.009/2      # 30.0045
}

df_mg = df.copy()
for ion, w in eq_wt.items():
    df_mg[ion] = df_mg[ion] * w  # mg/L = meq/L * (mg/meq)


expected_ions = list(eq_wt.keys())
missing = [ion for ion in expected_ions if ion not in df_mg.columns]
if missing:
    raise KeyError(f"Missing required ion columns: {missing}")

# ensure a 'Label' column exists (use index if you don't have a sample-name column)
if 'Label' not in df_mg.columns:
    df_mg['Label'] = df_mg.index.astype(str)

if 'Color' not in df_mg.columns:
    df_mg['Color'] = '#1f77b4'  # default blue

if 'Marker' not in df_mg.columns:
    df_mg['Marker'] = 'o'  # default marker

if 'Size' not in df_mg.columns:
    df_mg['Size'] = 50  # default size

if 'Alpha' not in df_mg.columns:
    df_mg['Alpha'] = 0.7  # default transparency

# ---- Plot with unit="mg/L" (stable path in wqchartpy) ----
triangle_piper.plot(
    df_mg,
    unit="mg/L",
    figname="piper_plot_from_meqL",
    figformat="png"
)

print("✅ Saved: piper_plot_from_meqL.png")
# Out:
# Trilinear Piper plot created. Saving it to /workspaces/fernanda-stuff/fernanda-stuff/SRV (project 6)
#
# ✅ Saved: piper_plot_from_meqL.png

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Understanding Water Chemistry Data Format
#
# WQChartPy requires data in a specific format. Let's examine the required columns:

# %%
from wqchartpy import triangle_piper

# Load the template dataset
df = pd.read_csv('C:\Users\fermunari\Desktop\UofA\Projects\Project 6\piperplot.xlsx')

# Display the data
print("\nData shape:", df.shape)
df
# Out:
#   Cell In[20], line 4
#     df = pd.read_csv('C:\Users\fermunari\Desktop\UofA\Projects\Project 6\piperplot.xlsx')
#                                                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# ### Required Columns Explained:
#
# 1. **Sample**: Sample name or ID
# 2. **Label**: Group identifier (used for categorizing samples)
# 3. **Color**: Color for plotting (matplotlib color names or hex codes)
# 4. **Marker**: Marker style for plotting (matplotlib marker codes)
# 5. **Size**: Marker size for plotting
# 6. **Alpha**: Transparency (0 = transparent, 1 = opaque)
# 7. **pH**: pH value
# 8. **Major Ions**: Ca, Mg, Na, K, HCO3, CO3, Cl, SO4 (all in mg/L)
# 9. **TDS**: Total Dissolved Solids (mg/L)

# %%
# Basic statistics for the template data
print("Basic Statistics for Template Dataset:")
print("======================================")

# Select only the chemical parameter columns
chem_cols = ['pH', 'Ca', 'Mg', 'Na', 'K', 'HCO3', 'CO3', 'Cl', 'SO4', 'TDS']
df_summary = df[chem_cols].describe().round(2)
# Out:
# Basic Statistics for Template Dataset:
# ======================================

# %%
df_summary
# Out:
#          pH      Ca     Mg     Na     K    HCO3  CO3     Cl     SO4     TDS
# count  6.00    6.00   6.00   6.00  6.00    6.00  6.0   6.00    6.00    6.00
# mean   7.52   61.00  13.67  25.00  2.60  217.50  0.0  33.33   30.83  394.33
# std    0.25   36.57   6.38   8.37  2.13   81.15  0.0  32.75   37.26  151.74
# min    7.10   32.00   6.00  16.00  0.50   73.00  0.0  11.00    9.00  233.00
# 25%    7.43   47.00  11.00  19.00  1.12  202.50  0.0  15.00    9.00  314.25
# 50%    7.55   50.00  11.00  25.00  2.60  225.50  0.0  18.00    9.50  368.50
# 75%    7.68   53.00  18.50  27.25  2.80  267.25  0.0  36.75   38.50  412.25
# max    7.80  134.00  22.00  39.00  6.40  305.00  0.0  96.00  100.00  673.00

# %%
print("\nSample Groups:")
df['Label'].value_counts()
# Out:
# Sample Groups:
# Label
# Cluster_A    2
# Cluster_B    2
# Cluster_C    2
# Name: count, dtype: int64

# %%
print("TDS Range by Group:")
for group in df['Label'].unique():
    group_data = df[df['Label'] == group]
    print(f"{group}: {group_data['TDS'].min():.1f} - {group_data['TDS'].max():.1f} mg/L")
# Out:
# TDS Range by Group:
# Cluster_A: 233.0 - 673.0 mg/L
# Cluster_B: 299.0 - 377.0 mg/L
# Cluster_C: 360.0 - 424.0 mg/L

# %% [markdown]
# ## Your First Hydrogeochemical Plot: Piper Diagram
#
# The Piper diagram is one of the most widely used plots in hydrogeochemistry. It shows the relative concentrations of major cations and anions.

# %%
# Import the triangle Piper module
from wqchartpy import triangle_piper

triangle_piper.plot(
    df, unit='mg/L', 
    figname='./plots/example_triangle_piper', figformat='png'
)
# Out:
# Trilinear Piper plot created. Saving it to /workspaces/hwrs564a_course_materials_arbennett/content_weekly/week_05

# %% [markdown]
# ## Understanding the Piper Diagram
#
# The Piper diagram consists of:
# - **Left triangle**: Cations (Ca²⁺, Mg²⁺, Na⁺+K⁺)
# - **Right triangle**: Anions (Cl⁻, SO₄²⁻, HCO₃⁻+CO₃²⁻)
# - **Central diamond**: Combined cation and anion composition
#
# ### Interpretation:
# - Points closer to corners indicate dominance of that ion
# - Points in the center indicate mixed water types
# - Clustering indicates similar water chemistry

# %% [markdown]
# ## Creating Multiple Plot Types
#
# Let's create several different plot types to compare their strengths:

# %%
# Stiff diagram - creates unique 'fingerprints' for each water sample
from wqchartpy import stiff

stiff.plot(
    df,  unit='mg/L', 
    figname='./plots/stiff_diagram_example', figformat='png'
)
# Out:
# Stiff plot created for sample1. Saving it to /workspaces/hwrs564a_course_materials_arbennett/content_weekly/week_05
#
# Stiff plot created for sample2. Saving it to /workspaces/hwrs564a_course_materials_arbennett/content_weekly/week_05
#
# Stiff plot created for sample3. Saving it to /workspaces/hwrs564a_course_materials_arbennett/content_weekly/week_05
#
# Stiff plot created for sample4. Saving it to /workspaces/hwrs564a_course_materials_arbennett/content_weekly/week_05
#
# Stiff plot created for sample5. Saving it to /workspaces/hwrs564a_course_materials_arbennett/content_weekly/week_05
#
# Stiff plot created for sample6. Saving it to /workspaces/hwrs564a_course_materials_arbennett/content_weekly/week_05

# %%
# Gibbs diagram - helps identify water-rock interaction processes
from wqchartpy import gibbs

gibbs.plot(
    df, unit='mg/L', 
    figname='./plots/gibbs_example', figformat='png'
)
# Out:
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# Gibbs plot created. Saving it to /workspaces/hwrs564a_course_materials_arbennett/content_weekly/week_05
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive
# findfont: Generic family 'cursive' not found because none of the following families were found: Apple Chancery, Textile, Zapf Chancery, Sand, Script MT, Felipa, Comic Neue, Comic Sans MS, cursive

# %%
# Schoeller diagram - shows ion concentrations on a log scale
# Note: https://github.com/jyangfsu/WQChartPy/blob/main/wqchartpy/schoeller.py#L56-L76
from wqchartpy import schoeller

fig = schoeller.plot(
    df, unit='mg/L', 
    figname='./plots/schoeller', figformat='png'
)
# Out:
# Schoeller diagram created. Saving it to /workspaces/hwrs564a_course_materials_arbennett/content_weekly/week_05

# %%
fig

# %% [markdown]
# ## Data Summary and Statistics

# %% [markdown]
# ## Exercise: Create Your Own Plot
#
# Try modifying the data and creating a new plot:

# %%
# Exercise: Modify colors and create a new Piper diagram
df_modified = df.copy()
df_modified
# Out:
#     Sample      Label  Color Marker  Size  Alpha   pH   Ca  Mg  Na    K  HCO3  \
# 0  sample1  Cluster_A    red      o    30    0.6  7.8   32   6  28  2.8    73
# 1  sample2  Cluster_B  green      s    30    0.6  7.6   46  11  17  0.7   201
# 2  sample3  Cluster_B  green      s    30    0.6  7.5   54  11  16  2.4   207
# 3  sample4  Cluster_C   blue      ^    30    0.6  7.7   50  11  25  2.8   244
# 4  sample5  Cluster_C   blue      ^    30    0.6  7.4   50  22  25  0.5   305
# 5  sample6  Cluster_A    red      o    30    0.6  7.1  134  21  39  6.4   275
#
#    CO3  Cl  SO4  TDS
# 0    0  43   48  233
# 1    0  14    9  299
# 2    0  18   10  377
# 3    0  18    9  360
# 4    0  11    9  424
# 5    0  96  100  673

# %%
df_modified.index = df_modified['Label']

# %%
df_modified
# Out:
#             Sample      Label  Color Marker  Size  Alpha   pH   Ca  Mg  Na  \
# Label
# Cluster_A  sample1  Cluster_A    red      o    30    0.6  7.8   32   6  28
# Cluster_B  sample2  Cluster_B  green      s    30    0.6  7.6   46  11  17
# Cluster_B  sample3  Cluster_B  green      s    30    0.6  7.5   54  11  16
# Cluster_C  sample4  Cluster_C   blue      ^    30    0.6  7.7   50  11  25
# Cluster_C  sample5  Cluster_C   blue      ^    30    0.6  7.4   50  22  25
# Cluster_A  sample6  Cluster_A    red      o    30    0.6  7.1  134  21  39
#
#              K  HCO3  CO3  Cl  SO4  TDS
# Label
# Cluster_A  2.8    73    0  43   48  233
# Cluster_B  0.7   201    0  14    9  299
# Cluster_B  2.4   207    0  18   10  377
# Cluster_C  2.8   244    0  18    9  360
# Cluster_C  0.5   305    0  11    9  424
# Cluster_A  6.4   275    0  96  100  673

# %%
# Change colors for each cluster - how to do this??

# Create the plot with modified colors
triangle_piper.plot(df_modified, 
                   unit='mg/L', 
                   figname='./plots/modified_piper', 
                   figformat='png')

print("Modified Piper diagram created with new colors!")

# %% [markdown]
# ## Key Takeaways
#
# 1. **Data Format**: WQChartPy requires specific column names and format
# 2. **Multiple Plot Types**: Different plots reveal different aspects of water chemistry
# 3. **Customization**: Colors, markers, and sizes can be customized for better visualization
# 4. **Interpretation**: Each plot type has specific interpretation guidelines
